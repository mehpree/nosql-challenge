ude'}},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({},
                           [
    {
      $set: {
        'geocode.longitude': { $toDouble: '$geocode.longitude' },
        'geocode.latitude': { $toDouble: '$geocode.latitude' }
      }
    }
  ]
);
# Out:
# ---------------------------------------------------------------------------
# WriteError                                Traceback (most recent call last)
# c:\Users\sharm\Desktop\UofT BootCamp Challenges\nosql-challenge\Resources\NoSQL_setup.ipynb Cell 28 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/sharm/Desktop/UofT%20BootCamp%20Challenges/nosql-challenge/Resources/NoSQL_setup.ipynb#Y113sZmlsZQ%3D%3D?line=0'>1</a> # Change the data type from String to Decimal for longitude and latitude
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sharm/Desktop/UofT%20BootCamp%20Challenges/nosql-challenge/Resources/NoSQL_setup.ipynb#Y113sZmlsZQ%3D%3D?line=1'>2</a> establishments.update_many({}, [{'$set': {'geocode.longitude': {'$toDouble': '$geocode.longitude'},
#       <a href='vscode-notebook-cell:/c%3A/Users/sharm/Desktop/UofT%20BootCamp%20Challenges/nosql-challenge/Resources/NoSQL_setup.ipynb#Y113sZmlsZQ%3D%3D?line=2'>3</a>                                          'geocode.latitude': {'$toDouble': '$geocode.latitude'}
#       <a href='vscode-notebook-cell:/c%3A/Users/sharm/Desktop/UofT%20BootCamp%20Challenges/nosql-challenge/Resources/NoSQL_setup.ipynb#Y113sZmlsZQ%3D%3D?line=3'>4</a>                                          }
#       <a href='vscode-notebook-cell:/c%3A/Users/sharm/Desktop/UofT%20BootCamp%20Challenges/nosql-challenge/Resources/NoSQL_setup.ipynb#Y113sZmlsZQ%3D%3D?line=4'>5</a>                                 }
#       <a href='vscode-notebook-cell:/c%3A/Users/sharm/Desktop/UofT%20BootCamp%20Challenges/nosql-challenge/Resources/NoSQL_setup.ipynb#Y113sZmlsZQ%3D%3D?line=5'>6</a>                                ]
#       <a href='vscode-notebook-cell:/c%3A/Users/sharm/Desktop/UofT%20BootCamp%20Challenges/nosql-challenge/Resources/NoSQL_setup.ipynb#Y113sZmlsZQ%3D%3D?line=6'>7</a>                           )
#
# File c:\Users\sharm\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:1104, in Collection.update_many(self, filter, update, upsert, array_filters, bypass_document_validation, collation, hint, session)
#    1100 common.validate_list_or_none('array_filters', array_filters)
#    1102 write_concern = self._write_concern_for(session)
#    1103 return UpdateResult(
# -> 1104     self._update_retryable(
#    1105         filter, update, upsert, check_keys=False, multi=True,
#    1106         write_concern=write_concern,
#    1107         bypass_doc_val=bypass_document_validation,
#    1108         collation=collation, array_filters=array_filters,
#    1109         hint=hint, session=session),
#    1110     write_concern.acknowledged)
#
# File c:\Users\sharm\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:877, in Collection._update_retryable(self, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session)
#     868 def _update(session, sock_info, retryable_write):
#     869     return self._update(
#     870         sock_info, criteria, document, upsert=upsert,
#     871         check_keys=check_keys, multi=multi, manipulate=manipulate,
#    (...)
#     874         array_filters=array_filters, hint=hint, session=session,
#     875         retryable_write=retryable_write)
# --> 877 return self.__database.client._retryable_write(
#     878     (write_concern or self.write_concern).acknowledged and not multi,
#     879     _update, session)
#
# File c:\Users\sharm\anaconda3\envs\dev\lib\site-packages\pymongo\mongo_client.py:1552, in MongoClient._retryable_write(self, retryable, func, session)
#    1550 """Internal retryable write helper."""
#    1551 with self._tmp_session(session) as s:
# -> 1552     return self._retry_with_session(retryable, func, s, None)
#
# File c:\Users\sharm\anaconda3\envs\dev\lib\site-packages\pymongo\mongo_client.py:1438, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1429 """Execute an operation with at most one consecutive retries
#    1430
#    1431 Returns func()'s return value on success. On error retries the same
#    (...)
#    1434 Re-raises any exception thrown by func().
#    1435 """
#    1436 retryable = (retryable and self.retry_writes
#    1437              and session and not session.in_transaction)
# -> 1438 return self._retry_internal(retryable, func, session, bulk)
#
# File c:\Users\sharm\anaconda3\envs\dev\lib\site-packages\pymongo\mongo_client.py:1470, in MongoClient._retry_internal(self, retryable, func, session, bulk)
#    1468                 raise last_error
#    1469             retryable = False
# -> 1470         return func(session, sock_info, retryable)
#    1471 except ServerSelectionTimeoutError:
#    1472     if is_retrying():
#    1473         # The application may think the write was never attempted
#    1474         # if we raise ServerSelectionTimeoutError on the retry
#    1475         # attempt. Raise the original exception instead.
#
# File c:\Users\sharm\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:869, in Collection._update_retryable.<locals>._update(session, sock_info, retryable_write)
#     868 def _update(session, sock_info, retryable_write):
# --> 869     return self._update(
#     870         sock_info, criteria, document, upsert=upsert,
#     871         check_keys=check_keys, multi=multi, manipulate=manipulate,
#     872         write_concern=write_concern, op_id=op_id, ordered=ordered,
#     873         bypass_doc_val=bypass_doc_val, collation=collation,
#     874         array_filters=array_filters, hint=hint, session=session,
#     875         retryable_write=retryable_write)
#
# File c:\Users\sharm\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:846, in Collection._update(self, sock_info, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, retryable_write)
#     836 # The command result has to be published for APM unmodified
#     837 # so we make a shallow copy here before adding updatedExisting.
#     838 result = sock_info.command(
#     839     self.__database.name,
#     840     command,
#    (...)
#     844     client=self.__database.client,
#     845     retryable_write=retryable_write).copy()
# --> 846 _check_write_command_response(result)
#     847 # Add the updatedExisting field for compatibility.
#     848 if result.get('n') and 'upserted' not in result:
#
# File c:\Users\sharm\anaconda3\envs\dev\lib\site-packages\pymongo\helpers.py:229, in _check_write_command_response(result)
#     227 write_errors = result.get("writeErrors")
#     228 if write_errors:
# --> 229     _raise_last_write_error(write_errors)
#     231 error = result.get("writeConcernError")
#     232 if error:
#
# File c:\Users\sharm\anaconda3\envs\dev\lib\site-packages\pymongo\helpers.py:211, in _raise_last_write_error(write_errors)
#     209 if error.get("code") == 11000:
#     210     raise DuplicateKeyError(error.get("errmsg"), 11000, error)
# --> 211 raise WriteError(error.get("errmsg"), error.get("code"), error)
#
# WriteError: Unsupported conversion from object to double in $convert with no onError value, full error: {'index': 0, 'code': 241, 'errmsg': 'Unsupported conversion from object to double in $convert with no onError value'}

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{'$set' : {"RatingValue" : {"$toInt" : "$RatingValue"}}}])

# %%
# Check that the coordinates and rating value are now numbers
import pandas as pd
path = "../Resources/establishments.json"
df = pd.read_json(path)
df.head()
# Out:
#     FHRSID  ChangesByServerID LocalAuthorityBusinessID        BusinessName  \
# 0   254719                  0             PI/000069980   Refreshment Kiosk
# 1  1034540                  0             PI/000078691  The Coastguard Inn
# 2   254250                  0             PI/000066174     The Pines Calyx
# 3   551803                  0             PI/000070948        The Tea Room
# 4   632212                  0             PI/000043474         Lenox House
#
#                         BusinessType  BusinessTypeID       AddressLine1  \
# 0            Restaurant/Cafe/Canteen               1            The Bay
# 1                  Pub/bar/nightclub            7843            The Bay
# 2            Other catering premises            7841   The Pines Garden
# 3            Restaurant/Cafe/Canteen               1   The Pines Garden
# 4  Hotel/bed & breakfast/guest house            7842  27 Granville Road
#
#        AddressLine2      AddressLine3 AddressLine4  ...  \
# 0  St Margarets Bay              Kent               ...
# 1  St Margarets Bay              Kent               ...
# 2        Beach Road  St Margarets Bay         Kent  ...
# 3        Beach Road  St Margarets Bay         Kent  ...
# 4  St Margarets Bay              Kent               ...
#
#       LocalAuthorityWebSite     LocalAuthorityEmailAddress  \
# 0  http://www.dover.gov.uk/  publicprotection@dover.gov.uk
# 1  http://www.dover.gov.uk/  publicprotection@dover.gov.uk
# 2  http://www.dover.gov.uk/  publicprotection@dover.gov.uk
# 3  http://www.dover.gov.uk/  publicprotection@dover.gov.uk
# 4  http://www.dover.gov.uk/  publicprotection@dover.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode  RightToReply  \
# 0  {'longitude': '1.387974', 'latitude': '51.1522...
# 1  {'longitude': '1.387974', 'latitude': '51.1522...
# 2  {'longitude': '1.383298', 'latitude': '51.1481...
# 3  {'longitude': '1.383298', 'latitude': '51.1481...
# 4  {'longitude': '1.385585', 'latitude': '51.1524...
#
#       Distance NewRatingPending  \
# 0  4587.347175            False
# 1  4587.347175            False
# 2  4587.362403            False
# 3  4587.362403            False
# 4  4587.440907            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [5 rows x 27 columns]

# %%
# Check that the coordinates and rating value are now numbers
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6503acf891e6667971850194'),
#  'geocode': {'latitude': {'$toDouble': '$geocode.latitude'},
#              'longitude': {'$toDouble': '$geocode.longitude'}},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
